# %% [markdown]
# # Data Cleaning

# %%
# for data manipulation
import numpy as np
import pandas as pd
import os

from scipy.stats.stats import pearsonr

import matplotlib.pyplot as plt

import pickle

# %%
game_data_path = "data/final_game_data/"
files = os.listdir(game_data_path)
season = pd.read_csv(game_data_path + files[0])

# %%
season.shape
# Out:
# (2632, 98)

# %%
season.columns
# Out:
# Index(['Unnamed: 0', 'team', 'opponent', 'date', 'index', 'team_STL%',
#        'team_FT', 'team_2PA', 'team_FG', 'team_DRB', 'team_ORB%', 'team_AST',
#        'team_3PAr', 'team_PF', 'team_FGA', 'team_DRBr', 'team_2P', 'team_ORBr',
#        'team_TOV%', 'team_AST%', 'team_FTAr', 'team_FIC', 'team_eFG%',
#        'team_FG%', 'team_2PAr', 'team_+/-', 'team_USG%', 'team_DRtg',
#        'team_2P%', 'team_DRB%', 'team_ORtg', 'team_TRB%', 'team_ORB',
#        'team_3P', 'team_TOV', 'team_STL/TOV', 'team_TSA', 'team_AST/TOV',
#        'team_3PA', 'team_BLK%', 'team_FT%', 'team_PTS', 'team_HOB', 'team_STL',
#        'team_TRB', 'team_FTA', 'team_BLK', 'team_FTr', 'team_TS%',
#        'team_FT/FGA', 'team_3P%', 'opponent_STL%', 'opponent_FT',
#        'opponent_2PA', 'opponent_FG', 'opponent_DRB', 'opponent_ORB%',
#        'opponent_AST', 'opponent_3PAr', 'opponent_PF', 'opponent_FGA',
#        'opponent_DRBr', 'opponent_2P', 'opponent_ORBr', 'opponent_TOV%',
#        'opponent_AST%', 'opponent_FTAr', 'opponent_FIC', 'opponent_eFG%',
#        'opponent_FG%', 'opponent_2PAr', 'opponent_+/-', 'opponent_USG%',
#        'opponent_DRtg', 'opponent_2P%', 'opponent_DRB%', 'opponent_ORtg',
#        'opponent_TRB%', 'opponent_ORB', 'opponent_3P', 'opponent_TOV',
#        'opponent_STL/TOV', 'opponent_TSA', 'opponent_AST/TOV', 'opponent_3PA',
#        'opponent_BLK%', 'opponent_FT%', 'opponent_PTS', 'opponent_HOB',
#        'opponent_STL', 'opponent_TRB', 'opponent_FTA', 'opponent_BLK',
#        'opponent_FTr', 'opponent_TS%', 'opponent_FT/FGA', 'opponent_3P%',
#        'home'],
#       dtype='object')

# %%
['team', 'opponent', 'date', 'team_STL%',
       'team_FT', 'team_2PA', 'team_FG', 'team_DRB', 'team_ORB%', 'team_AST',
       'team_3PAr', 'team_PF', 'team_FGA', 'team_DRBr', 'team_2P', 'team_ORBr',
       'team_TOV%', 'team_AST%', 'team_FTAr', 'team_FIC', 'team_eFG%',
       'team_FG%', 'team_2PAr', 'team_+/-', 'team_USG%', 'team_DRtg',
       'team_2P%', 'team_DRB%', 'team_ORtg', 'team_TRB%', 'team_ORB',
       'team_3P', 'team_TOV', 'team_STL/TOV', 'team_TSA', 'team_AST/TOV',
       'team_3PA', 'team_BLK%', 'team_FT%', 'team_PTS', 'team_HOB', 'team_STL',
       'team_TRB', 'team_FTA', 'team_BLK', 'team_FTr', 'team_TS%',
       'team_FT/FGA', 'team_3P%', 'opponent_STL%', 'opponent_FT',
       'opponent_2PA', 'opponent_FG', 'opponent_DRB', 'opponent_ORB%',
       'opponent_AST', 'opponent_3PAr', 'opponent_PF', 'opponent_FGA',
       'opponent_DRBr', 'opponent_2P', 'opponent_ORBr', 'opponent_TOV%',
       'opponent_AST%', 'opponent_FTAr', 'opponent_FIC', 'opponent_eFG%',
       'opponent_FG%', 'opponent_2PAr', 'opponent_+/-', 'opponent_USG%',
       'opponent_DRtg', 'opponent_2P%', 'opponent_DRB%', 'opponent_ORtg',
       'opponent_TRB%', 'opponent_ORB', 'opponent_3P', 'opponent_TOV',
       'opponent_STL/TOV', 'opponent_TSA', 'opponent_AST/TOV', 'opponent_3PA',
       'opponent_BLK%', 'opponent_FT%', 'opponent_PTS', 'opponent_HOB',
       'opponent_STL', 'opponent_TRB', 'opponent_FTA', 'opponent_BLK',
       'opponent_FTr', 'opponent_TS%', 'opponent_FT/FGA', 'opponent_3P%',
       'home']

# %%
team = "Golden State Warriors"
team_games = season[season.team == team]

# %%
team_list = pd.unique(season.team)
correlations = [0 for j in range(len(team_games.columns[6:]))]

for i, col in enumerate(team_games.columns[6:]):
    tot_data = []
    tot_out = []
    
    for team in team_list:
        team_games = season[season.team == team]
        out = np.array(team_games.team_PTS + team_games.opponent_PTS)
        out = out[1:]
        tot_out.extend(out)

        data = np.array(team_games[col])[:-1]
        tot_data.extend(data)
    
    correlations[i] = np.corrcoef(tot_data,tot_out)[1][0]
        
    #break
        
correlations = np.array(correlations)

# %%
cols = season.columns
corr = np.abs(correlations)
corr, cols = zip(*sorted(zip(corr, cols), reverse=True))
corr = np.array(corr)
cols = np.array(cols)

# %%
cols
# Out:
# array(['team_FTAr', 'team_STL/TOV', 'team_ORtg', 'opponent', 'team_FG',
#        'team_DRBr', 'team_ORB%', 'team_ORB', 'team_STL%', 'Unnamed: 0',
#        'team_HOB', 'team_BLK%', 'team_DRtg', 'team_eFG%', 'team_2P',
#        'team_ORBr', 'date', 'team_2PAr', 'team', 'team_3PA', 'team_2P%',
#        'team_TOV%', 'team_FT', 'team_STL', 'team_FIC', 'team_AST/TOV',
#        'team_TRB', 'team_PTS', 'team_FGA', 'index', 'team_DRB',
#        'team_AST', 'team_TOV', 'team_FT%', 'team_+/-', 'team_AST%',
#        'team_2PA', 'team_TRB%', 'team_3P', 'team_FTA', 'team_FG%',
#        'team_3PAr', 'team_DRB%', 'team_USG%', 'team_PF', 'team_TSA',
#        'opponent_FTAr', 'opponent_ORtg', 'opponent_FG',
#        'opponent_STL/TOV', 'team_TS%', 'opponent_ORB%', 'team_FTr',
#        'opponent_DRBr', 'opponent_3PA', 'opponent_STL%', 'team_FT/FGA',
#        'opponent_ORB', 'opponent_FIC', 'opponent_2PA', 'opponent_DRtg',
#        'opponent_eFG%', 'opponent_2P%', 'opponent_USG%', 'opponent_2P',
#        'opponent_ORBr', 'opponent_2PAr', 'opponent_BLK%', 'opponent_HOB',
#        'team_BLK', 'opponent_AST/TOV', 'opponent_FG%', 'opponent_TOV%',
#        'opponent_FT', 'opponent_+/-', 'opponent_AST%', 'opponent_TOV',
#        'opponent_FGA', 'opponent_PTS', 'opponent_STL', 'opponent_TSA',
#        'opponent_PF', 'opponent_TRB%', 'opponent_3PAr', 'opponent_3P',
#        'team_3P%', 'opponent_TRB', 'opponent_AST', 'opponent_DRB',
#        'opponent_FT%', 'opponent_FTA', 'opponent_DRB%'], dtype='<U16')

# %%
season = season.drop(["team_FTAr", 'Unnamed: 0'], axis = 1)
to_remove = list(cols[corr < 0.08])
to_keep = ["date", "team", "opponent"]
for t in to_keep:
    if t in to_remove: to_remove.remove(t)
# Out:
# /Users/alexandrebucquet/anaconda2/envs/cs229proj/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less

# %%
season = season.drop(to_remove, axis = 1)

# %%
season
# Out:
#                         team                opponent       date  team_STL%  \
# 0      Golden State Warriors               Utah Jazz  200710300        7.6
# 1                  Utah Jazz   Golden State Warriors  200710300        8.6
# 2         Los Angeles Lakers         Houston Rockets  200710300       17.2
# 3            Houston Rockets      Los Angeles Lakers  200710300       10.7
# 4          San Antonio Spurs  Portland Trail Blazers  200710300        8.7
# 5     Portland Trail Blazers       San Antonio Spurs  200710300        1.1
# 6        Cleveland Cavaliers        Dallas Mavericks  200710310       12.8
# 7           Dallas Mavericks     Cleveland Cavaliers  200710310        7.0
# 8             Denver Nuggets     Seattle SuperSonics  200710310       10.2
# 9        Seattle SuperSonics          Denver Nuggets  200710310        8.3
# 10            Indiana Pacers      Washington Wizards  200710310       11.0
# 11        Washington Wizards          Indiana Pacers  200710310        5.5
# 12         Memphis Grizzlies       San Antonio Spurs  200710310        5.2
# 13         San Antonio Spurs       Memphis Grizzlies  200710310        8.3
# 14           New Jersey Nets           Chicago Bulls  200710310        9.1
# 15             Chicago Bulls         New Jersey Nets  200710310        7.1
# 16       New Orleans Hornets        Sacramento Kings  200710310        6.4
# 17          Sacramento Kings     New Orleans Hornets  200710310        5.4
# 18             Orlando Magic         Milwaukee Bucks  200710310        2.3
# 19           Milwaukee Bucks           Orlando Magic  200710310        4.5
# 20           Toronto Raptors      Philadelphia 76ers  200710310        8.8
# 21        Philadelphia 76ers         Toronto Raptors  200710310        3.3
# 22                Miami Heat         Detroit Pistons  200711010        4.4
# 23           Detroit Pistons              Miami Heat  200711010       12.2
# 24       Seattle SuperSonics            Phoenix Suns  200711010        9.3
# 25              Phoenix Suns     Seattle SuperSonics  200711010       10.3
# 26                 Utah Jazz         Houston Rockets  200711010        6.2
# 27           Houston Rockets               Utah Jazz  200711010        9.3
# 28             Atlanta Hawks        Dallas Mavericks  200711020        6.5
# 29          Dallas Mavericks           Atlanta Hawks  200711020        4.3
# ...                      ...                     ...        ...        ...
# 2602          Boston Celtics         Detroit Pistons  200805220        6.2
# 2603         Detroit Pistons          Boston Celtics  200805220       11.1
# 2604      Los Angeles Lakers       San Antonio Spurs  200805230        8.7
# 2605       San Antonio Spurs      Los Angeles Lakers  200805230        7.6
# 2606         Detroit Pistons          Boston Celtics  200805240       13.7
# 2607          Boston Celtics         Detroit Pistons  200805240        7.5
# 2608       San Antonio Spurs      Los Angeles Lakers  200805250        4.3
# 2609      Los Angeles Lakers       San Antonio Spurs  200805250        5.4
# 2610         Detroit Pistons          Boston Celtics  200805260        8.8
# 2611          Boston Celtics         Detroit Pistons  200805260        3.8
# 2612       San Antonio Spurs      Los Angeles Lakers  200805270        8.0
# 2613      Los Angeles Lakers       San Antonio Spurs  200805270        5.7
# 2614          Boston Celtics         Detroit Pistons  200805280        8.9
# 2615         Detroit Pistons          Boston Celtics  200805280        8.9
# 2616      Los Angeles Lakers       San Antonio Spurs  200805290       10.3
# 2617       San Antonio Spurs      Los Angeles Lakers  200805290        5.7
# 2618         Detroit Pistons          Boston Celtics  200805300        3.8
# 2619          Boston Celtics         Detroit Pistons  200805300       10.1
# 2620          Boston Celtics      Los Angeles Lakers  200806050        6.7
# 2621      Los Angeles Lakers          Boston Celtics  200806050        9.0
# 2622          Boston Celtics      Los Angeles Lakers  200806080        8.0
# 2623      Los Angeles Lakers          Boston Celtics  200806080        9.1
# 2624      Los Angeles Lakers          Boston Celtics  200806100        4.6
# 2625          Boston Celtics      Los Angeles Lakers  200806100        9.2
# 2626      Los Angeles Lakers          Boston Celtics  200806120        6.7
# 2627          Boston Celtics      Los Angeles Lakers  200806120        7.9
# 2628      Los Angeles Lakers          Boston Celtics  200806150       11.6
# 2629          Boston Celtics      Los Angeles Lakers  200806150        6.3
# 2630          Boston Celtics      Los Angeles Lakers  200806170       19.1
# 2631      Los Angeles Lakers          Boston Celtics  200806170        4.2
#
#       team_FG  team_ORB%  team_DRBr  team_DRtg  team_ORtg  team_ORB  ...   \
# 0        32.0       14.9   0.810811      111.3       91.3       7.0  ...
# 1        41.0       34.8   0.714286       91.3      111.3      16.0  ...
# 2        32.0       22.9   0.702703      102.1       99.9      11.0  ...
# 3        34.0       31.6   0.755102       99.9      102.1      12.0  ...
# 4        41.0       27.3   0.700000      105.7      115.5      12.0  ...
# 5        39.0       22.2   0.800000      115.5      105.7       8.0  ...
# 6        28.0       34.0   0.659574      107.1       86.1      16.0  ...
# 7        33.0       13.9   0.861111       86.1      107.1       5.0  ...
# 8        42.0       25.5   0.740000       95.4      111.1      13.0  ...
# 9        40.0       27.5   0.730769      111.1       95.4      14.0  ...
# 10       38.0       29.8   0.750000      101.2      109.5      14.0  ...
# 11       36.0       35.4   0.589286      109.5      101.2      23.0  ...
# 12       38.0       14.6   0.857143      108.5      105.4       6.0  ...
# 13       38.0       16.3   0.833333      105.4      108.5       7.0  ...
# 14       33.0       35.0   0.708333      104.5      113.6      14.0  ...
# 15       38.0       35.8   0.577778      113.6      104.5      19.0  ...
# 16       39.0       29.7   0.750000       96.7      111.8      11.0  ...
# 17       36.0       19.5   0.764706      111.8       96.7       8.0  ...
# 18       32.0       23.1   0.785714       94.2      115.7       9.0  ...
# 19       33.0       35.3   0.625000      115.7       94.2      18.0  ...
# 20       41.0       24.4   0.729730      106.8      116.7      10.0  ...
# 21       38.0       35.7   0.673913      116.7      106.8      15.0  ...
# 22       33.0       13.5   0.875000      100.8       88.6       5.0  ...
# 23       31.0       25.5   0.727273       88.6      100.8      12.0  ...
# 24       41.0       22.0   0.780000       99.0       92.5      11.0  ...
# 25       42.0       11.4   0.886364       92.5       99.0       5.0  ...
# 26       36.0       31.9   0.659091      109.9       98.5      15.0  ...
# 27       39.0       23.7   0.780488       98.5      109.9       9.0  ...
# 28       36.0       31.1   0.730769      101.8      109.4      14.0  ...
# 29       35.0       15.6   0.815789      109.4      101.8       7.0  ...
# ...       ...        ...        ...        ...        ...       ...  ...
# 2602     35.0       37.1   0.666667      127.0      119.6      13.0  ...
# ...            ...           ...           ...              ...           ...
# 2602           4.0         0.451      0.605313         0.394366      0.500000
# 2603           6.0         0.347      0.584337         0.305556      0.263158
# 2604           1.0         0.115      0.388403         0.057471      0.260870
# 2605           7.0         0.282      0.632832         0.253521      0.277778
# 2606           3.0         0.435      0.571776         0.362319      0.357143
# 2607           9.0         0.356      0.473709         0.315068      0.076923
# 2608           0.0         0.207      0.469379         0.097561      0.352941
# 2609           4.0         0.311      0.612221         0.229730      0.555556
# 2610           3.0         0.591      0.450938         0.484848      0.111111
# 2611          10.0         0.371      0.577112         0.285714      0.222222
# 2612           3.0         0.224      0.498072         0.164706      0.214286
# 2613           4.0         0.347      0.526377         0.320000      0.291667
# 2614           5.0         0.567      0.609173         0.432836      0.523810
# 2615           3.0         0.411      0.614849         0.328767      0.533333
# 2616           3.0         0.243      0.561523         0.175676      0.466667
# 2617           6.0         0.212      0.538097         0.188235      0.380952
# 2618           4.0         0.375      0.530520         0.277778      0.277778
# 2619           7.0         0.304      0.517638         0.246377      0.285714
# 2620           2.0         0.364      0.492611         0.272727      0.214286
# 2621           3.0         0.461      0.536105         0.368421      0.315789
# 2622           1.0         0.120      0.583524         0.120482      0.476190
# 2623           3.0         0.559      0.637394         0.397059      0.642857
# 2624           8.0         0.265      0.436987         0.180723      0.444444
# 2625           6.0         0.493      0.518104         0.304348      0.428571
# 2626           4.0         0.384      0.568448         0.315068      0.363636
# 2627           3.0         0.377      0.506907         0.272727      0.285714
# 2628           2.0         0.403      0.540600         0.311688      0.363636
# 2629           7.0         0.392      0.555915         0.291139      0.296296
# 2630           0.0         0.594      0.569871         0.437500      0.370370
# 2631           4.0         0.425      0.634198         0.367816      0.500000
#
#       home
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
# 5        0
# 6        1
# 7        0
# 8        1
# 9        0
# 10       1
# 11       0
# 12       1
# 13       0
# 14       1
# 15       0
# 16       1
# 17       0
# 18       1
# 19       0
# 20       1
# 21       0
# 22       1
# 23       0
# 24       1
# 25       0
# 26       1
# 27       0
# 28       1
# 29       0
# ...    ...
# 2602     1
# 2603     0
# 2604     1
# 2605     0
# 2606     1
# 2607     0
# 2608     1
# 2609     0
# 2610     1
# 2611     0
# 2612     1
# 2613     0
# 2614     1
# 2615     0
# 2616     1
# 2617     0
# 2618     1
# 2619     0
# 2620     1
# 2621     0
# 2622     1
# 2623     0
# 2624     1
# 2625     0
# 2626     1
# 2627     0
# 2628     1
# 2629     0
# 2630     1
# 2631     0
#
# [2632 rows x 29 columns]

# %%
season.columns
# Out:
# Index(['team', 'opponent', 'date', 'team_STL%', 'team_FG', 'team_ORB%',
#        'team_DRBr', 'team_DRtg', 'team_ORtg', 'team_ORB', 'team_STL/TOV',
#        'team_BLK%', 'team_HOB', 'team_FTr', 'team_TS%', 'opponent_STL%',
#        'opponent_FG', 'opponent_ORB%', 'opponent_DRBr', 'opponent_FTAr',
#        'opponent_ORtg', 'opponent_STL/TOV', 'opponent_3PA', 'opponent_BLK',
#        'opponent_FTr', 'opponent_TS%', 'opponent_FT/FGA', 'opponent_3P%',
#        'home'],
#       dtype='object')

# %% [markdown]
# ## Matchup data

# %%
game_data_path = "data/matchups/"
files = os.listdir(game_data_path)
with open(game_data_path + files[2], 'rb') as f:
    season = pickle.load(f, encoding='latin1')

# %%
season.shape
# Out:
# (30, 547)

# %%
season.head(5)
# Out:
#            Team 2007_points-per-game Last 3_points-per-game  \
# 0  Golden State                108.6                  115.0
# 1       Phoenix                108.0                  106.0
# 2          Utah                106.9                  111.7
# 3        Denver                106.1                  110.7
# 4     LA Lakers                106.0                  109.7
#
#   Last 1_points-per-game Home_points-per-game Away_points-per-game  \
# 0                  113.0                111.9                105.8
# 1                  110.0                108.8                107.2
# 2                  120.0                110.9                103.3
# 3                  123.0                111.0                100.6
# 4                   96.0                107.2                104.4
#
#   2006_points-per-game 2007_average-scoring-margin  \
# 0                106.6                        +0.7
# 1                109.5                        +5.4
# 2                100.9                        +8.8
# 3                104.4                        +3.8
# 4                103.0                        +4.1
#
#   Last 3_average-scoring-margin Last 1_average-scoring-margin  \
# 0                         +13.7                         +19.0
# 1                          -5.7                          +4.0
# 2                         +10.3                         +24.0
# 3                          -4.7                         +16.0
# 4                          +3.7                         -24.0
#
#              ...            Last 1_opponent-technical-fouls-per-game  \
# 0            ...                                                 1.0
# 1            ...                                                 0.0
# 2            ...                                                 1.0
# 3            ...                                                 0.0
# 4            ...                                                 0.0
#
#   Home_opponent-technical-fouls-per-game  \
# 0                                    0.3
# 1                                    0.1
# 2                                    0.1
# 3                                    0.7
# 4                                    0.3
#
#   Away_opponent-technical-fouls-per-game  \
# 0                                    0.4
# 1                                    0.1
# 2                                    0.0
# 3                                    0.1
# 4                                    0.0
#
#   2006_opponent-technical-fouls-per-game 2007_possessions-per-game  \
# 0                                    0.5                     101.7
# 1                                    0.3                     102.0
# 2                                    0.4                      99.0
# 3                                    0.3                     104.6
# 4                                    0.4                     100.1
#
#   Last 3_possessions-per-game Last 1_possessions-per-game  \
# 0                       103.5                        99.9
# 1                       104.0                       108.4
# 2                        95.1                        99.3
# 3                       110.3                       108.5
# 4                       101.3                        99.3
#
#   Home_possessions-per-game Away_possessions-per-game  \
# 0                     102.2                     101.3
# 1                     102.2                     101.7
# 2                      98.5                      99.4
# 3                     105.4                     103.7
# 4                     100.3                      99.8
#
#   2006_possessions-per-game
# 0                     102.1
# 1                      99.2
# 2                      95.1
# 3                     100.5
# 4                      98.1
#
# [5 rows x 547 columns]

# %%
to_drop = []
unique_cols = []
for col in season.columns:
    if "200" in col: to_drop.append(col)
    if "Home" in col: unique_cols.append(col)

# %%
small = season.drop(to_drop, axis = 1)

# %%
small.shape
# Out:
# (30, 365)

# %%
unique_cols
# Out:
# ['Home_points-per-game',
#  'Home_average-scoring-margin',
#  'Home_offensive-efficiency',
#  'Home_1st-quarter-points-per-game',
#  'Home_2nd-quarter-points-per-game',
#  'Home_3rd-quarter-points-per-game',
#  'Home_4th-quarter-points-per-game',
#  'Home_overtime-points-per-game',
#  'Home_points-in-paint-per-game',
#  'Home_fastbreak-points-per-game',
#  'Home_average-biggest-lead',
#  'Home_average-1st-quarter-margin',
#  'Home_average-2nd-quarter-margin',
#  'Home_average-3rd-quarter-margin',
#  'Home_average-4th-quarter-margin',
#  'Home_average-overtime-margin',
#  'Home_average-margin-thru-3-quarters',
#  'Home_points-from-2-pointers',
#  'Home_points-from-3-pointers',
#  'Home_shooting-pct',
#  'Home_effective-field-goal-pct',
#  'Home_three-point-pct',
#  'Home_two-point-pct',
#  'Home_free-throw-pct',
#  'Home_field-goals-made-per-game',
#  'Home_field-goals-attempted-per-game',
#  'Home_three-pointers-made-per-game',
#  'Home_three-pointers-attempted-per-game',
#  'Home_free-throws-made-per-game',
#  'Home_free-throws-attempted-per-game',
#  'Home_three-point-rate',
#  'Home_two-point-rate',
#  'Home_fta-per-fga',
#  'Home_offensive-rebounds-per-game',
#  'Home_defensive-rebounds-per-game',
#  'Home_team-rebounds-per-game',
#  'Home_total-rebounds-per-game',
#  'Home_offensive-rebounding-pct',
#  'Home_defensive-rebounding-pct',
#  'Home_blocks-per-game',
#  'Home_steals-per-game',
#  'Home_block-pct',
#  'Home_assists-per-game',
#  'Home_turnovers-per-game',
#  'Home_assist--per--turnover-ratio',
#  'Home_assists-per-fgm',
#  'Home_personal-fouls-per-game',
#  'Home_technical-fouls-per-game',
#  'Home_opponent-points-per-game',
#  'Home_opponent-average-scoring-margin',
#  'Home_defensive-efficiency',
#  'Home_opponent-1st-quarter-points-per-game',
#  'Home_opponent-2nd-quarter-points-per-game',
#  'Home_opponent-3rd-quarter-points-per-game',
#  'Home_opponent-4th-quarter-points-per-game',
#  'Home_opponent-overtime-points-per-game',
#  'Home_opponent-points-in-paint-per-game',
#  'Home_opponent-fastbreak-points-per-game',
#  'Home_opponent-average-biggest-lead',
#  'Home_opponent-points-from-2-pointers',
#  'Home_opponent-points-from-3-pointers',
#  'Home_opponent-shooting-pct',
#  'Home_opponent-effective-field-goal-pct',
#  'Home_opponent-three-point-pct',
#  'Home_opponent-two-point-pct',
#  'Home_opponent-free-throw-pct',
#  'Home_opponent-field-goals-made-per-game',
#  'Home_opponent-field-goals-attempted-per-game',
#  'Home_opponent-three-pointers-made-per-game',
#  'Home_opponent-three-pointers-attempted-per-game',
#  'Home_opponent-free-throws-made-per-game',
#  'Home_opponent-free-throws-attempted-per-game',
#  'Home_opponent-three-point-rate',
#  'Home_opponent-two-point-rate',
#  'Home_opponent-fta-per-fga',
#  'Home_opponent-offensive-rebounds-per-game',
#  'Home_opponent-defensive-rebounds-per-game',
#  'Home_opponent-team-rebounds-per-game',
#  'Home_opponent-total-rebounds-per-game',
#  'Home_opponent-offensive-rebounding-pct',
#  'Home_opponent-defensive-rebounding-pct',
#  'Home_opponent-blocks-per-game',
#  'Home_opponent-steals-per-game',
#  'Home_opponent-block-pct',
#  'Home_opponent-assists-per-game',
#  'Home_opponent-turnovers-per-game',
#  'Home_opponent-assist--per--turnover-ratio',
#  'Home_opponent-assists-per-fgm',
#  'Home_opponent-personal-fouls-per-game',
#  'Home_opponent-technical-fouls-per-game',
#  'Home_possessions-per-game']

# %%
['Home_1st-quarter-points-per-game',
 'Home_2nd-quarter-points-per-game',
 'Home_3rd-quarter-points-per-game',
 'Home_4th-quarter-points-per-game',
 'Home_overtime-points-per-game',
 'Home_average-1st-quarter-margin',
 'Home_average-2nd-quarter-margin',
 'Home_average-3rd-quarter-margin',
 'Home_average-4th-quarter-margin',
 'Home_average-overtime-margin',
 'Home_average-margin-thru-3-quarters',
]
