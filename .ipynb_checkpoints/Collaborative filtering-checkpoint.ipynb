# %% [markdown]
# # Collaborative Filtering

# %%
# for data manipulation
import numpy as np
import pandas as pd
import os

# use surprise for collaborative filtering
from surprise import Reader, Dataset
from surprise import SVD, evaluate
from surprise import NMF

# %% [markdown]
# ## Read in data

# %% [markdown]
# #### Game data

# %%
game_data_path = "data/final_game_data/"
files = os.listdir(game_data_path)
season = pd.read_csv(game_data_path + files[0])

# %%
season.shape
# Out:
# (2632, 98)

# %% [markdown]
# #### Odds data

# %%
odds_data_path = "data/odds_data_processed/"
odds_files = os.listdir(odds_data_path)

# %%
odds = pd.read_csv(odds_data_path + odds_files[1])

# %%
odds.shape
# Out:
# (1288, 14)

# %% [markdown]
# #### Reconciling names

# %%
season_names = {'Golden State Warriors':'GSW',
                'Los Angeles Lakers': 'LAL',
                'San Antonio Spurs': 'SAS',
                'Cleveland Cavaliers': 'CLE',
                'Denver Nuggets': 'DEN',
                'Indiana Pacers': 'IND',
                'Memphis Grizzlies': 'MEM',
                'New Jersey Nets': 'BRK',
                'Brooklyn Nets': 'BRK',
                'New Orleans Hornets': 'NOP',
                'New Orleans Pelicans': 'NOP',
                'Orlando Magic': 'ORL',
                'Toronto Raptors': 'TOR',
                'Miami Heat': 'MIA',
                'Seattle SuperSonics': 'SEA',
                'Utah Jazz': 'UTA',
                'Atlanta Hawks': 'ATL',
                'Boston Celtics': 'BOS',
                'Charlotte Bobcats': 'CHA',
                'Charlotte Hornets': 'CHA',
                'Chicago Bulls': 'CHI',
                'Los Angeles Clippers': 'LAC',
                'Minnesota Timberwolves': 'MIN',
                'Phoenix Suns': 'PHO',
                'Dallas Mavericks': 'DAL',
                'Houston Rockets': 'HOU',
                'Milwaukee Bucks': 'MIL',
                'Philadelphia 76ers': 'PHI',
                'Washington Wizards': 'WAS',
                'Detroit Pistons': 'DET',
                'New York Knicks': 'NYK',
                'Sacramento Kings': 'SAC',
                'Portland Trail Blazers': 'POR',
                'Oklahoma City Thunder': 'OKC'
        }
odds_names = {}
for name in list(pd.unique(odds.Home)):
    found = False
    for s_name in season_names:
        if name in s_name:
            found = True
            odds_names[name] = season_names[s_name]
    if not found: print(name)
odds_names["LA Lakers"] = "LAL"
odds_names["LA Clippers"] = "LAC"
odds_names["Okla City"] = "OKC"
# Out:
# LA Lakers
# LA Clippers

# %%
odds["Home"] = odds["Home"].apply(lambda x: odds_names[x])
odds["Away"] = odds["Away"].apply(lambda x: odds_names[x])

season["team"] = season["team"].apply(lambda x: season_names[x])
season["opponent"] = season["opponent"].apply(lambda x: season_names[x])

# %% [markdown]
# #### Merging the two data tables

# %%
def make_index(row, col1, col2, col3):
    return str(row[col1]) + str(row[col2]) + str(row[col3])

season["date"] = season["date"].apply(lambda x: str(x)[:-1])

season["Index"] = season.apply(lambda x: make_index(x, "date", "team", "opponent"), axis=1)

odds["Date"] = odds["Date"].apply(lambda x: "".join(x.split("-")))

odds["Index"] = odds.apply(lambda x: make_index(x, "Date", "Home", "Away"), axis=1)

merged = pd.merge(odds, season, on='Index')

merged = merged.drop(["Unnamed: 0_x", "Unnamed: 0_y", "date", "Home", "Away", "index"], axis = 1)

# %%
merged.sample(1)
# Out:
#         Date     OU  Spread OU_2H Spread_2H ML_home ML_away  Points  \
# 67  20071109  201.0     8.5  97.5       7.0     315    -375     207
#
#     Win Margin  2H Points  ...   opponent_HOB opponent_STL opponent_TRB  \
# 67          -5         92  ...       1.564103         12.0         43.0
#
#    opponent_FTA  opponent_BLK  opponent_FTr  opponent_TS%  opponent_FT/FGA  \
# 67         15.0           5.0         0.169      0.554393         0.146067
#
#     opponent_3P%  home
# 67      0.454545     1
#
# [1 rows x 107 columns]

# %%
data = merged.set_index("Index")
#data = data.drop(["index"], axis = 1)
data = data.sort_index()

# %%
data.shape
# Out:
# (1285, 106)

# %%
data.head(5)
# Out:
#                     Date     OU  Spread  OU_2H Spread_2H ML_home ML_away  \
# Index
# 20071030GSWUTA  20071030  214.5     3.0  105.5       3.0    -120     100
# 20071030LALHOU  20071030  191.0     2.5     99         3     190    -230
# 20071030SASPOR  20071030  184.0    12.5     95         5   -1400     900
# 20071031BRKCHI  20071031  188.0     2.0     94         3    -125     105
# 20071031CLEDAL  20071031  186.0     3.0   91.5       4.0     120    -140
#
#                 Points  Win Margin  2H Points  ...   opponent_HOB  \
# Index                                          ...
# 20071030GSWUTA     213         -21        100  ...       1.585366
# 20071030LALHOU     188          -2        102  ...       1.676471
# 20071030SASPOR     203           9         95  ...       1.384615
# 20071031BRKCHI     215           9         95  ...       1.605263
# 20071031CLEDAL     166         -18         78  ...       1.696970
#
#                opponent_STL opponent_TRB  opponent_FTA  opponent_BLK  \
# Index
# 20071030GSWUTA          9.0         56.0          36.0           7.0
# 20071030LALHOU         10.0         49.0          31.0           5.0
# 20071030SASPOR          1.0         40.0          17.0           4.0
# 20071031BRKCHI          7.0         45.0          26.0           3.0
# 20071031CLEDAL          6.0         36.0          20.0           8.0
#
#                 opponent_FTr  opponent_TS%  opponent_FT/FGA  opponent_3P%  \
# Index
# 20071030GSWUTA         0.400      0.552721         0.333333      0.454545
# 20071030LALHOU         0.419      0.541990         0.283784      0.272727
# 20071030SASPOR         0.218      0.567384         0.166667      0.461538
# 20071031BRKCHI         0.271      0.479337         0.197917      0.347826
# 20071031CLEDAL         0.290      0.591260         0.246377      0.500000
#
#                 home
# Index
# 20071030GSWUTA     1
# 20071030LALHOU     1
# 20071030SASPOR     1
# 20071031BRKCHI     1
# 20071031CLEDAL     1
#
# [5 rows x 106 columns]

# %%
dates = pd.unique(data.Date)
prev_games = 5

# %%
for i, date in enumerate(dates):
    if i < prev_games: continue
    
    window = dates[i - prev_games:i + 1] ### train also on the games we intend to predict
    
    window_data = data.loc[data['Date'].isin(window)]
    
    break

# %%
window_data
# Out:
#                     Date     OU  Spread  OU_2H Spread_2H ML_home ML_away  \
# Index
# 20071030GSWUTA  20071030  214.5     3.0  105.5       3.0    -120     100
# 20071030LALHOU  20071030  191.0     2.5     99         3     190    -230
# 20071030SASPOR  20071030  184.0    12.5     95         5   -1400     900
# 20071031BRKCHI  20071031  188.0     2.0     94         3    -125     105
# 20071031CLEDAL  20071031  186.0     3.0   91.5       4.0     120    -140
# 20071031DENSEA  20071031  213.0    10.5  107.5       6.5    -825     625
# 20071104LACSEA         0.265      0.544886         0.216867      0.384615
# 20071104LALUTA         0.439      0.557032         0.317073      0.214286
# 20071104MIACHA         0.319      0.571937         0.260870      0.444444
# 20071104NYKMIN         0.115      0.508753         0.068966      0.529412
# 20071104PHOCLE         0.136      0.493139         0.102273      0.312500
# 20071104TORBOS         0.273      0.568182         0.233766      0.461538
#
#                 home
# Index
# 20071030GSWUTA     1
# 20071030LALHOU     1
# 20071030SASPOR     1
# 20071031BRKCHI     1
# 20071031CLEDAL     1
# 20071031DENSEA     1
# 20071031INDWAS     1
# 20071031MEMSAS     1
# 20071031NOPSAC     1
# 20071031ORLMIL     1
# 20071031TORPHI     1
# 20071101MIADET     1
# 20071101SEAPHO     1
# 20071101UTAHOU     1
# 20071102ATLDAL     1
# 20071102BOSWAS     1
# 20071102BRKTOR     1
# 20071102CHAMIL     1
# 20071102CHIPHI     1
# 20071102CLENYK     1
# 20071102INDMIA     1
# 20071102LACGSW     1
# 20071102MINDEN     1
# 20071102NOPPOR     1
# 20071102ORLDET     1
# 20071102PHOLAL     1
# 20071102SASSAC     1
# 20071103DALSAC     1
# 20071103HOUPOR     1
# 20071103MEMIND     1
# 20071103MILCHI     1
# 20071103PHIBRK     1
# 20071103UTAGSW     1
# 20071103WASORL     1
# 20071104DENNOP     1
# 20071104DETATL     1
# 20071104LACSEA     1
# 20071104LALUTA     1
# 20071104MIACHA     1
# 20071104NYKMIN     1
# 20071104PHOCLE     1
# 20071104TORBOS     1
#
# [42 rows x 106 columns]

# %%
ratings_dict = {'itemID': list(window_data.team),
                'userID': list(window_data.opponent),
                'rating': list(window_data.Points)}
df = pd.DataFrame(ratings_dict)

# A reader is still needed but only the rating_scale param is required.
# The Reader class is used to parse a file containing ratings.
reader = Reader(rating_scale=(75, 280))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(df[['userID', 'itemID', 'rating']], reader)

# %%
# Split data into 5 folds
data.split(n_folds=10)

# svd
algo = SVD()
evaluate(algo, data, measures=['RMSE'])

# nmf
#algo = NMF()
#evaluate(algo, data, measures=['RMSE'])
# Out:
# Evaluating RMSE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 21.9268
# ------------
# Fold 2
# RMSE: 24.8165
# ------------
# Fold 3
# RMSE: 16.8152
# ------------
# Fold 4
# RMSE: 20.0221
# ------------
# Fold 5
# RMSE: 25.6183
# ------------
# Fold 6
# RMSE: 20.8589
# ------------
# Fold 7
# RMSE: 18.0143
# ------------
# Fold 8
# RMSE: 27.9684
# ------------
# Fold 9
# RMSE: 26.9383
# ------------
# Fold 10
# RMSE: 8.7339
# ------------
# ------------
# Mean RMSE: 21.1713
# ------------
# ------------
# CaseInsensitiveDefaultDict(list,
#                            {'rmse': [21.92683931452358,
#                              24.816483647309763,
#                              16.8152145544159,
#                              20.022095178904127,
#                              25.61829526217621,
#                              20.858868830466076,
#                              18.014326568744057,
#                              27.9683897928155,
#                              26.938316899530314,
#                              8.733857789281021]})

# %%
train = data.build_full_trainset()
algo.train(train)

# %%
user_id = "MEM"
item_id = "SAS"

print(algo.predict(user_id, item_id, 100))
print(algo.predict(item_id, user_id, 100))
# Out:
# user: MEM        item: SAS        r_ui = 100.00   est = 196.59   {'was_impossible': False}
# user: SAS        item: MEM        r_ui = 100.00   est = 204.97   {'was_impossible': False}
